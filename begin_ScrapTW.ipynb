# %%
import tweepy as tw
import pandas as pd
import re
import glob
import os
import schedule
import time
from textblob import TextBlob 
from datetime import datetime
import requests

# %run ./fair_keys.ipynb

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)


url = "https://api.aiforthai.in.th/ssense"
headers = {'Apikey': "0kFkiFLdf4TAyY3JeUT9WVnB5naP6SjW"}

# %%
import pandas as pd
import re
import glob
filename = ['tweet_data_2032022.csv','tweet_data_1932022.csv','tweet_data_2132022_1.csv','tweet_data_2232022.csv']
i = 0
for file in filename:
    df1 = pd.read_csv(file)
    if i != 0:
        df = pd.concat([df,df1])
        df.drop_duplicates(keep='last',inplace=True)
    else:
        df = df1
        i += 1

df['Time'] = pd.to_datetime(df['Time']).dt.strftime('%Y/%m/%d')
df['Time'] = pd.to_datetime(df['Time'])
df.sort_values(by=['Time','Keyword'],inplace=True)

#df['Time'] = pd.to_datetime(df['Time'])
time = list(set(df['Time'].tolist()))
mask = (df['Time']>='2022-03-19') & (df['Time']<='2022-03-21')
df.loc[mask]
# Out:
#           Keyword             User  Retweet  Likes  \
# 55      animation  SagarGa39569425      0.0    0.0
# 68      animation  Aarya_pimparkar      0.0    0.0
# 77      animation         jkhomezi      0.0    0.0
# 165     animation    blazingwish66      0.0    0.0
# 167     animation        DI0RDENKI      0.0    0.0
# ...           ...              ...      ...    ...
# 1209  อนิเมะแนะนำ      tinyreview2     37.0    0.0
# 1220  อนิเมะแนะนำ      cara_mellox      2.0    0.0
# 1221  อนิเมะแนะนำ      btf_effectx      2.0    1.0
# 1222  อนิเมะแนะนำ      mydissocute      2.0    0.0
# 1223  อนิเมะแนะนำ       bingboom17     37.0    0.0
#
#                                                   Tweet       Time Language  \
# 55    The plot of "Don't Mess With The Cultivation B... 2022-03-19      NaN
# 68    I love the art style in "Love After Marriage" ... 2022-03-19      NaN
# 77    You'll find companies looking for a "Graphic D... 2022-03-19      NaN
# 165   The plot of "Martial Rebel" is like a roller c... 2022-03-19      NaN
# 167   I think diluc should get a new idle animation ... 2022-03-19      NaN
# ...                                                 ...        ...      ...
# 1209                                RT bbrinkk bilibili 2022-03-21       th
# 1220                         RT btfeffectx 86 EIGHTYSIX 2022-03-21       th
# 1221                       86 EIGHTYSIX Attack on Titan 2022-03-21       th
# 1222                         RT btfeffectx 86 EIGHTYSIX 2022-03-21       th
# 1223                                RT bbrinkk bilibili 2022-03-21       th
#
#                   User Location      Hashtag  Polarity  Sentiment
# 55                          NaN          NaN       NaN        NaN
# 68                          NaN          NaN       NaN        NaN
# 77                          NaN          NaN       NaN        NaN
# 165                         NaN          NaN       NaN        NaN
# 167                         NaN          NaN       NaN        NaN
# ...                         ...          ...       ...        ...
# 1209                  ประเทศไทย  ['สาววายถ']  positive      97.30
# 1220  รักพี่บาจิเหมือนหมา 4ever           []  negative      66.67
# 1221           she/her, th-en ♡           []  positive      83.33
# 1222                        NaN           []  negative      66.67
# 1223                        NaN  ['สาววายถ']  positive      97.30
#
# [6498 rows x 11 columns]

# %%
# cursor = tw.Cursor(api.user_timeline,
#                             id='Fa6i7r2',
#                             tweet_mode="extended",
#                             since = '2022-03-17',
#                             include_entities=True).items(10)

cursor = tw.Cursor(api.search_tweets,
                            id='Fa6i7r2',
                            tweet_mode="extended",
                            since = '2022-03-17',
                            include_entities=True).items(10)
for tweet in cursor:
    #if "RT @" not in tweet.full_text:
    print([tweet.full_text,tweet.retweet_count,tweet.favorite_count])
    print(str(tweet.created_at))
# Out:
# Unexpected parameter: id
# Unexpected parameter: include_entities
# Unexpected parameter: id
# Unexpected parameter: include_entities
# ['RT @PatheNeuro: ในฐานะแพทย์ระบบประสาทและสมอง ไม่มีวิตามินอาหารเสริมบำรุงสมองนะครับ  อาหารหลักห้าหมู่ที่ถูกสัดส่วนคือจบครบแล้ว', 89609, 0]
# 2022-02-14 12:37:52+00:00
# ['ทุกความรู้สึกที่อยู่ภายในจิตใจ', 0, 0]
# 2022-01-31 20:41:23+00:00
# ['RT @23jpeg: อย่าทิ้งใครไว้ในเพลงโปรดอีกเลย จังหวะที่ได้ยินเพลงนี้แล้วนึกถึงเขา ทั้งๆที่หลุดจากวงโคจรของกันและกันไปแล้วมันเศร้า', 25664, 0]
# 2022-01-18 17:55:15+00:00
# ['なんでもない', 0, 0]
# 2022-01-18 17:55:00+00:00
# ['เป็นห่วง?', 0, 0]
# 2022-01-09 20:20:27+00:00
# ['RT @pepi_nim_: ดูเสร็จคือกุอินโทรเวิดหนักกว่าเดิมแล้วหนึ่ง  https://t.co/onBrFk03yX', 47791, 0]
# 2022-01-05 12:48:59+00:00
# ['RT @itmydefinition: นั่นสิ ตอบไม่ได้เหมือนกัน https://t.co/lFom2jp8Tg', 27520, 0]
# 2022-01-05 12:47:57+00:00
# ['ชอบ...', 0, 0]
# 2022-01-04 21:22:38+00:00
# ['@khunto21 😏', 0, 0]
# 2021-12-28 16:01:42+00:00
# ['RT @kikipaloa: เวลามีคนจำเรื่องเล็กๆน้อยๆของเราได้หรือเรื่องที่เคยบอกมันใจฟูจริงๆนะ แบบเขาจำได้ยังไงนะขนาดตัวกูเองแค่เรื่องเมื่อเช้ายังลืมเ…', 34742, 0]
# 2021-12-15 20:06:40+00:00
# ['RT @xmicstye: อีกเดือนเดียวก็ใกล้จะหมดปีแล้ว ไม่รู้ว่าที่ผ่านมาไปทำตัวส้นตีนใส่ใครไว้บ้าง เดี๋ยวปีหน้าเอาใหม่จะส้นตีนให้มากกว่าเดิม', 23363, 0]
# 2021-12-04 16:59:36+00:00
# ['RT @532am_: เราไม่ควรไปโกรธหรือฟึดฟัดใส่ใครเพียงแค่เพราะว่าเราหิวข้าว', 48948, 0]
# 2021-11-29 22:20:21+00:00
# ['RT @itmydefinition: เคยเป็นปะที่แบบอยู่ดีๆ ก็รู้สึกว่าคำนี้สะกดแปลกๆ ทั้งที่เป็นคำง่ายๆ ที่ใช้ในชีวิตประจำวัน แต่รู้สึกไม่คุ้น จนต้องไปเสิ…', 77919, 0]
# 2021-11-18 09:27:43+00:00
# ["RT @nchdaq: ยกให้เพลงข้างกัน-three man down เป็นอีกเพลงที่โคตรคลั่งรัก 'เมืองนี้ไม่เหงาอีกต่อไปต่อจากนี้ฉันมีเธอ' เป็นเพลงที่ฟังในช่วงที่คว…", 31286, 0]
# 2021-08-09 18:50:20+00:00
# ['RT @yoxrgravity: ‘จงเป็นตัวเองในแบบที่เขาหาไม่ได้จากใคร’', 53311, 0]
# 2021-08-08 18:42:17+00:00
# ['RT @coolkidneverhot: มึงเคยปล่อยให้คนอื่นเข้าใจผิดเพราะขี้เกียจอธิบายป่ะ', 93091, 0]
# 2021-08-06 17:16:40+00:00
# ['RT @yoxrgravity: แอบเข้าใจบริบทที่ว่าเป็นเพื่อนกันน่ะดีแล้ว จะได้ไม่ต้องเลิกกัน เพราะส่วนใหญ่คือเป็นแฟนพอเลิกกันก็ห่างหายกันไปจนเสียดายความ…', 34829, 0]
# 2021-08-06 17:04:58+00:00
# ['RT @yoxrgravity: ‘อย่าดูถูกความเจ็บปวดของใคร ถ้าไม่รู้ว่าเขาต้องผ่านอะไรมาบ้าง’', 51143, 0]
# 2021-08-06 17:04:41+00:00
# ['RT @wednesdaynnc: ทุกคน เธรดนี้เราจะมาเล่าเกี่ยวกับ โรค อกหัก หรือ โรค Broken heart syndrome หรืออีกชื่อคือโรคหัวใจสลาย มีอยู่จริงค่ะ เราไป…', 55805, 0]
# 2021-08-05 16:35:35+00:00
# ['RT @youminimalism: https://t.co/ItzxvrwrUd', 249, 0]
# 2021-07-28 15:54:17+00:00
# ['RT @Dekchaikumkom: สำหรับใครที่สมหวังก็บอกได้สิ ว่าการรอมันคุ้มค่าอะ', 1025, 0]
# 2021-07-28 15:49:52+00:00
# ['RT @bbigkachu: พอถึงจุดๆนึงเราจะเข้าใจเองว่าการวิ่งตามเขาอยู่ฝ่ายเดียวมันไม่มีประโยชน์', 3727, 0]
# 2021-07-28 15:49:34+00:00
# ['RT @bbigkachu: เลิกคาดหวังกับความรักไปนานแล้ว', 8295, 0]
# 2021-07-28 06:40:29+00:00
# ['RT @yoxrgravity: รู้สึกเลยว่าช่วงนี้บางทีก็เผลอ toxic ใส่คนอื่น', 31228, 0]
# 2021-07-23 17:16:29+00:00
# ['เงียบ', 0, 0]
# 2021-07-23 17:16:23+00:00
# ['RT @mspinknherblue: อ่อนแอแล้วใครมาปกป้องอะ ก็ต้องเข้มแข็งปะ', 3163, 0]
# 2021-06-01 22:29:14+00:00
# ['RT @youminimalism: https://t.co/pKknvUKZqc', 593, 0]
# 2021-06-01 22:20:47+00:00
# ['RT @sfkkfs_: กฎข้อที่ 1 อย่าคลั่งรักจนตัวเองไม่มีความสุข', 27938, 0]
# 2021-05-23 20:17:00+00:00
# ['RT @mimilkss: อันนี้จริงนะ https://t.co/VegzcVH7KA', 12546, 0]
# 2021-05-19 20:17:08+00:00
# ['ทำไมถึงไม่มีใครคิดได้นะ ถ้าเค้าตายอำนาจจะไปอยู่ที่ใคร กูคงเป็นแบบพม่าแน่ๆ', 0, 0]
# 2021-05-13 19:26:08+00:00

# %%
today = datetime.today()
#filename = str("tweet_data_"+str(today.day)+str(today.month)+str(today.year)+".csv")
filename = 'tweet_data_2032022.csv'
df = pd.read_csv(filename)
# Out:
#           Keyword             User  Retweet  Likes  \
# 0              3d         Dominom_      0.0    0.0
# 1              3d        jannis_3d      0.0    0.0
# 2       animation      boringbambi      0.0    0.0
# 3       animation  depressedcule99      0.0    0.0
# 4       animation       NiiTawiah2      0.0    0.0
# ...           ...              ...      ...    ...
# 3476  sport anime  AliffMustafa180      1.0    1.0
# 3477  sport anime           yueme0      0.0    0.0
# 3478  sport anime      tsukinagass      0.0    0.0
# 3479  sport anime         kaitou_m      0.0    0.0
# 3480  sport anime          kjpboys      0.0    0.0
#
#                                                   Tweet  \
# 0     also next week is my last week of this class :...
# 1     @GriffinWB Butterflies you mean MOTH https://t...
# 2       Netflix needs to make more animation and kdrama
# 3     ShinobusMyGoat Ratio doenst work because im Ri...
# 4     The plot of The Supreme Expert is like a rolle...
# ...                                                 ...
# 3476       aimannadzmi1 LZJ is an MC from a sport anime
# 3477  Im literally hooked on this sport anime Its ab...
# 3478  THE OTHER ADULT SPORT ANIME IVE WATCHED IS ONE...
# 3479  On the sports anime side of things, this is wh...
# 3480  O54HEART attack on titan and demon slayer stro...
#
#                            Time
# 0     2022-03-21 06:27:16+00:00
# 1     2022-03-21 06:27:21+00:00
# 2     2022-03-20 14:13:00+00:00
# 3     2022-03-20 15:14:30+00:00
# 4     2022-03-20 14:43:23+00:00
# ...                         ...
# 3476  2022-03-19 22:11:35+00:00
# 3477  2022-03-19 20:59:34+00:00
# 3478  2022-03-20 05:22:46+00:00
# 3479  2022-03-21 04:38:17+00:00
# 3480  2022-03-20 06:53:42+00:00
#
# [3481 rows x 6 columns]

# %%
def getSentiment(text):
    # set sentiment
    if TextBlob(text).sentiment.polarity > 0:
        return 'positive'
    elif TextBlob(text).sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

def extract_hashtags(text):
    regex = "#(\w+)" 
    hashtag_list = re.findall(regex, text)
    return hashtag_list

def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
def get_related_tweets(key_word,date):
    tweet_keyword = []
    twitter_users = []
    twitter_users_location = []
    tweet_hashtag = []
    tweet_time = []
    tweet_string = [] 
    tweet_countRT = []
    tweet_fav = []
    tweet_sentiment = []
    tweet_polarity = []
    tweet_language = []
    if date != 'now':
        cursor = tw.Cursor(api.search_tweets,
                            q=key_word,
                            tweet_mode="extended",
                            since = date,
                            include_entities=True).items(30)
    else:
        cursor = tw.Cursor(api.search_tweets,
                            q=key_word,
                            tweet_mode="extended",
                            include_entities=True).items(30)
    for tweet in cursor:
                            
        if(tweet.lang == 'en' or tweet.lang == 'th'):
            twitter_users.append(tweet.user.screen_name)
            twitter_users_location.append(tweet.user.location)
            tweet_time.append(tweet.created_at)
            tweet_string.append(remove_url(tweet.full_text))
            tweet_countRT.append(tweet.retweet_count)
            tweet_fav.append(tweet.favorite_count)
            tweet_keyword.append(key_word)
            tweet_hashtag.append(str(extract_hashtags(tweet.full_text)))
            tweet_language.append(tweet.lang)
            if tweet.lang == 'en':
                tweet_polarity.append(getSentiment(tweet.full_text))
                tweet_sentiment.append(TextBlob(tweet.full_text).sentiment.polarity)
            elif tweet.lang == 'th':
                text = re.sub(r'[%]',' ',tweet.full_text)
                params = {'text':text}
                response = requests.get(url, headers=headers, params=params)
                try:
                    polarity = str(response.json()['sentiment']['polarity'])
                    sentiment = str(response.json()['sentiment']['score'])
                except (KeyError):
                    polarity = 'neutral'
                    sentiment = 0
                tweet_polarity.append(polarity)
                tweet_sentiment.append(sentiment)

    df = pd.DataFrame({'Keyword':tweet_keyword,'User':twitter_users,'Tweet': tweet_string,'Language':tweet_language, 'Time': tweet_time,'User Location':twitter_users_location,
                        'Hashtag':tweet_hashtag,'Polarity':tweet_polarity,'Likes':tweet_fav,'Retweet':tweet_countRT,'Sentiment':tweet_sentiment})

    return df

# %%
get_related_tweets(key_word,date)

# %%
for tweet in tw.Cursor(api.search_tweets,q='Genshin Impact',tweet_mode="extended",
                        include_entities=True,lang="en",since='2022-01-17').items(10):
    print('\n\nuser',tweet.user.screen_name)
    print('create',tweet.created_at)
    print('tweet',tweet.full_text)
    print('RT count',tweet.retweet_count)
    print('tweet fav',tweet.favorite_count)
    print('hashtag',extract_hashtags(tweet.full_text))
    print('language',tweet.lang)
    if tweet.lang == 'en':
        print('polarity',getSentiment(tweet.full_text))
        print('sentiment',TextBlob(tweet.full_text).sentiment.polarity)
    elif tweet.lang == 'th':
        text = tweet.full_text
        params = {'text':text}
        response = requests.get(url, headers=headers, params=params)
        print('polarity',response.json()['sentiment']['polarity'])
        print('sentiment',response.json()['sentiment']['score'])
# Out:
# Unexpected parameter: since
# user hibouxz
# create 2022-03-24 07:21:26+00:00
# tweet RT @litarnes: Reminders of home
#
# Childe ( Genshin Impact ) 原神 https://t.co/hOy0Q5BY6A
# RT count 7651
# tweet fav 0
# hashtag []
# language en
# polarity neutral
# sentiment 0.0
#
#
# user _berryrandom
# create 2022-03-24 07:21:21+00:00
# tweet RT @HoYoLAB_Mimo: 📘HoYoLAB's new content, "HoYoLAB Magazine," is now online!
#
# ✨This issue contains fantastic fan works of Genshin Impact, H…
# RT count 490
# tweet fav 0
# hashtag []
# language en
# polarity positive
# sentiment 0.2852272727272727
#
#
# user JosRd19
# create 2022-03-24 07:21:19+00:00
# tweet RT @racheltjhia: does anyone still play Genshin Impact? https://t.co/kjY6gTDoq9
# RT count 686
# tweet fav 0
# hashtag []
# language en
# polarity neutral
# sentiment 0.0
#
#
# user modrasolata
# create 2022-03-24 07:21:14+00:00
# tweet RT @litarnes: Reminders of home
#
# Childe ( Genshin Impact ) 原神 https://t.co/hOy0Q5BY6A
# RT count 7650
# tweet fav 0
# hashtag []
# language en
# polarity neutral
# sentiment 0.0
#
#
# user I_Leak_VN
# create 2022-03-24 07:21:11+00:00
# tweet RT @TechTabletscom: So overall the Exynos Galaxy S22 Ultra is quite disappointing. Over and over I see bad UI lag (Factory fixed it only fo…
# RT count 9
# tweet fav 0
# hashtag []
# language en
# polarity negative
# sentiment -0.23999999999999994
#
#
# user sleepyseelie
# create 2022-03-24 07:21:09+00:00
# tweet RT @nuletena: Little flower princess is visiting us today~
#
# #Genshin #GenshinImpact #Genshin_Impact
# #Sucrose #LittleSucrose https://t.co/8…
# RT count 3
# tweet fav 0
# hashtag ['Genshin', 'GenshinImpact', 'Genshin_Impact', 'Sucrose', 'LittleSucrose']
# language en
# polarity negative
# sentiment -0.1875
#
#
# user olaisafish
# create 2022-03-24 07:21:06+00:00
# tweet RT @naoki_dead: My eyes are up here😈
#
# #Genshin_Impact #GenshinImpact #Childe #Tartaglia https://t.co/mVdZh2yyC3
# RT count 4368
# tweet fav 0
# hashtag ['Genshin_Impact', 'GenshinImpact', 'Childe', 'Tartaglia']
# language en
# polarity neutral
# sentiment 0.0
#
#
# user c_2h5_oh
# create 2022-03-24 07:21:05+00:00
# tweet RT @naoki_dead: My eyes are up here😈
#
# #Genshin_Impact #GenshinImpact #Childe #Tartaglia https://t.co/mVdZh2yyC3
# RT count 4368
# tweet fav 0
# hashtag ['Genshin_Impact', 'GenshinImpact', 'Childe', 'Tartaglia']
# language en
# polarity neutral
# sentiment 0.0
#
#
# user brxwniee__
# create 2022-03-24 07:21:05+00:00
# tweet RT @naoki_dead: My eyes are up here😈
#
# #Genshin_Impact #GenshinImpact #Childe #Tartaglia https://t.co/mVdZh2yyC3
# RT count 4368
# tweet fav 0
# hashtag ['Genshin_Impact', 'GenshinImpact', 'Childe', 'Tartaglia']
# language en
# polarity neutral
# sentiment 0.0
#
#
# user pyxissh
# create 2022-03-24 07:21:04+00:00
# tweet RT @naoki_dead: My eyes are up here😈
#
# #Genshin_Impact #GenshinImpact #Childe #Tartaglia https://t.co/mVdZh2yyC3
# RT count 4368
# tweet fav 0
# hashtag ['Genshin_Impact', 'GenshinImpact', 'Childe', 'Tartaglia']
# language en
# polarity neutral
# sentiment 0.0
